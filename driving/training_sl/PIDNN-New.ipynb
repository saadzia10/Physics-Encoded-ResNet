# %%
import numpy as np
import pandas as pd
import pickle
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Input, Lambda
from tensorflow.keras.callbacks import ReduceLROnPlateau

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import plot_model
import os
import gc
from pathlib import Path

from pure_pursuit import *
import tensorflow as tf

import matplotlib.pyplot as plt

# %%
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
@tf.function
def get_max_dist(track_dists):
    return tf.reduce_max(track_dists, axis=1)

@tf.function
def get_max_dist_idx(track_dists):
    mask = track_dists[:, 9] != 200
    mask = tf.cast(mask, tf.int32)
    indices = tf.math.argmax(track_dists, output_type=tf.int32, axis=1)
    arr1 = indices * mask
    additional = tf.cast(track_dists[:, 9] == 200, tf.int32) * 9
    result = arr1 + additional

    return result

@tf.function
def compute_target_angle(track_dists):
    max_track_dist_idx = self.get_max_dist_idx(track_dists)

    max_dist_angle = max_track_dist_idx * 10 - 90
    return tf.cast(max_dist_angle, tf.float32) * RAD_PER_DEG

@tf.function
def compute_steering(data):

    target_angle = data[:, 1] * RAD_PER_DEG
    lookahead = data[:, 0]

    raw_steering_angle_rad = -tf.math.atan(
        (PURE_PURSUIT_2L * tf.math.sin(target_angle)) / (lookahead + 1e-7))

    raw_steering_angle_deg = raw_steering_angle_rad * DEG_PER_RAD

    normalized_steering_angle = tf.clip_by_value(raw_steering_angle_deg / MAX_STEERING_ANGLE_DEG, -1.0, 1.0)
    return normalized_steering_angle


model = load_model("PI_model_new_2/model.h5", custom_objects={'compute_steering': compute_steering})
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
[x.output_shape for x in model.layers[3].layers]
# Out:
# [[(None, 65)], (None, 32), (None, 16), (None, 8), (None, 2)]

# %%
model.

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_c (InputLayer)           [(None, 65)]         0           []
#
#  model_2 (Functional)           (None, 16)           2640        ['input_c[0][0]']
#
#  dense_c1 (Dense)               (None, 8)            136         ['model_2[0][0]']
#
#  model_1 (Functional)           (None, 2)            2794        ['input_c[0][0]']
#
#  dense_c2 (Dense)               (None, 4)            36          ['dense_c1[0][0]']
#
#  pp_based_steering (Lambda)     (None,)              0           ['model_1[0][0]']
#
#  residual (Dense)               (None, 1)            5           ['dense_c2[0][0]']
#
#  add (Add)                      (None, 1)            0           ['pp_based_steering[0][0]',
#                                                                   'residual[0][0]']
#
# ==================================================================================================
# Total params: 5,611
# Trainable params: 5,611
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %%
MODEL_SAVE_DIR = Path("PI_model_new_test")
if not MODEL_SAVE_DIR.exists():
    os.makedirs(MODEL_SAVE_DIR.as_posix())

# %% [markdown]
# ### Loading data files

# %%
train_files = []
val_files = []

path = Path("../../torcs_SL/data_all/data")
tracks = os.listdir(path.as_posix())

train_tracks = ['g-track-1', 'g-track-2', 'g-track-3', 'g-track-4', 'spring']
test_tracks = ['e-track-3', 'alpine-2', 'corkscrew', 'wheel-2']

random_tracks = np.random.choice(tracks, len(tracks), replace=False)
random_tracks = [x for x in random_tracks if x[:4] != 'dirt' and x[:3] != 'mix' and x not in test_tracks and x not in train_tracks]

val_tracks = random_tracks[:3]
    

track_files = list(path.glob("**/*.csv"))


train_track_files = [x for x in track_files if x.parts[-2] in train_tracks]
val_track_files = [x for x in track_files if x.parts[-2] in val_tracks]
train_track_files, val_track_files
# Out:
# ([PosixPath('../../torcs_SL/data_all/data/g-track-2/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-2/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-2/1.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-1/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-1/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-1/1.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-3/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-3/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/g-track-3/1.csv'),
#   PosixPath('../../torcs_SL/data_all/data/spring/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/spring/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/spring/1.csv')],
#  [PosixPath('../../torcs_SL/data_all/data/aalborg/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/aalborg/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/aalborg/1.csv'),
#   PosixPath('../../torcs_SL/data_all/data/brondehach/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/brondehach/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/brondehach/1.csv'),
#   PosixPath('../../torcs_SL/data_all/data/eroad/2.csv'),
#   PosixPath('../../torcs_SL/data_all/data/eroad/3.csv'),
#   PosixPath('../../torcs_SL/data_all/data/eroad/1.csv')])

# %% [raw]
# train_files = []
# val_files = []
#
# path = Path("data_big/data")
# # track_dirs = [path.joinpath('g-track-1')]
# # track_files = list(track_dirs[0].glob("*.csv"))
# # track_files = list(path.glob("*/*.csv"))
# # track_files
# track_files = list(path.glob("g-track*/*csv"))
# track_files

# %% [markdown]
# ### Train-Test Split

# %%
training_data = pd.DataFrame()
validation_data = pd.DataFrame()
split_ratio = 0.8

for fi in track_files[:int(split_ratio * len(track_files))]:
    training_data = pd.concat([training_data, pd.read_csv(fi)]).reset_index(drop=True)

for fi in track_files[int(split_ratio * len(track_files)):]:
    validation_data = pd.concat([validation_data, pd.read_csv(fi)]).reset_index(drop=True)

# %%
print (training_data.shape)
print (validation_data.shape)

# %%
training_data.columns.values

# %%
del training_data['Gear']
del validation_data['Gear']
del training_data[' CurrentLapTime']
del validation_data[' CurrentLapTime']
del training_data[' LastLapTime']
del validation_data[' LastLapTime']
del training_data[' Damage']
del validation_data[' Damage']
del training_data[' FuelLevel']
del validation_data[' FuelLevel']

del training_data[' DistanceFromStart']
del validation_data[' DistanceFromStart']

for col in [c for c in training_data.columns if c.strip()[:3] == "Opp"]:
    del training_data[col]
    del validation_data[col]

# %%
print (training_data.shape)
print (validation_data.shape)

# %%
training_data.columns

# %%
class PurePursuit:
    
    @staticmethod
    def get_max_dist(track):
        track_dists = np.array(track)
        return np.max(track_dists)
    
    @staticmethod
    def get_max_dist_idx(track):
        track_dists = np.array(track)
        if track_dists[9] == np.max(track_dists) or track_dists[9] == 200:
            return 9
        return np.argmax(track_dists)
    
    @staticmethod
    def compute_target_angle(track):

        max_track_dist_idx = PurePursuit.get_max_dist_idx(track)

        max_dist_angle = max_track_dist_idx * 10. - 90.
        return max_dist_angle 
    
    @staticmethod
    def get_lookahead(track):
        max_track_dist_idx = PurePursuit.get_max_dist_idx(track)
        return track[max_track_dist_idx]

# %%
training_data['target_angle'] = training_data.iloc[:, 8: 27].apply(lambda x : PurePursuit.compute_target_angle(x.values), axis=1)
validation_data['target_angle'] = training_data.iloc[:, 8: 27].apply(lambda x : PurePursuit.compute_target_angle(x.values), axis=1)

training_data['lookahead'] = training_data.iloc[:, 8: 27].apply(lambda x : PurePursuit.get_lookahead(x.values), axis=1)
validation_data['lookahead'] = training_data.iloc[:, 8: 27].apply(lambda x : PurePursuit.get_lookahead(x.values), axis=1)

# %% [markdown]
# ## PI Model Training

# %%
X_train=training_data.loc[:,[' Track_1',
       'Track_2', 'Track_3', 'Track_4', 'Track_5', 'Track_6', 'Track_7',
       'Track_8', 'Track_9', 'Track_10', 'Track_11', 'Track_12', 'Track_13',
       'Track_14', 'Track_15', 'Track_16', 'Track_17', 'Track_18', 'Track_19', 
        'TrackPosition', 'Angle', ' RPM', ' SpeedX', ' SpeedY', ' SpeedZ',
        ' WheelSpinVelocity_1', 'WheelSpinVelocity_2',
       'WheelSpinVelocity_3', 'WheelSpinVelocity_4', 'target_angle', 'lookahead']]

Y_train=training_data.loc[:,'Steering']
X_val=validation_data.loc[:,[' Track_1',
       'Track_2', 'Track_3', 'Track_4', 'Track_5', 'Track_6', 'Track_7',
       'Track_8', 'Track_9', 'Track_10', 'Track_11', 'Track_12', 'Track_13',
       'Track_14', 'Track_15', 'Track_16', 'Track_17', 'Track_18', 'Track_19', 
        'TrackPosition', 'Angle', ' RPM', ' SpeedX', ' SpeedY', ' SpeedZ',
        ' WheelSpinVelocity_1', 'WheelSpinVelocity_2',
       'WheelSpinVelocity_3', 'WheelSpinVelocity_4', 'target_angle', 'lookahead']]
Y_val=validation_data.loc[:,'Steering']

# %% [raw]
# X_train = X_train.values
# X_val = X_val.values
# Y_train = Y_train.values
# Y_val = Y_val.values

# %%
print (X_train.shape)
print (Y_train.shape)
print (X_val.shape)
print (Y_val.shape)
scaler = StandardScaler()
X_train.iloc[:, :-2]=scaler.fit_transform(X_train.iloc[:, :-2])
X_val.iloc[:, :-2]=scaler.fit_transform(X_val.iloc[:, :-2])
Y_train=Y_train.values
Y_val=Y_val.values
print (X_train.shape)
print (Y_train.shape)
print (X_val.shape)
print (Y_val.shape)

# %%
np.max(X_train['target_angle'])

# %% [markdown]
# ### Save these means and stds for test time

# %%
with open(MODEL_SAVE_DIR.joinpath("scaler.pickle").as_posix(), "wb") as fp:
    pickle.dump(scaler, fp)

# %%
scaler.mean_

# %%
scaler.scale_

# %%
np.save(MODEL_SAVE_DIR.joinpath("means.npy"), scaler.mean_)
np.save(MODEL_SAVE_DIR.joinpath("stds.npy"), scaler.scale_)

# %%
@tf.function
def get_max_dist(track_dists):
    return tf.reduce_max(track_dists, axis=1)

@tf.function
def get_max_dist_idx(track_dists):
    mask = track_dists[:, 9] != 200
    mask = tf.cast(mask, tf.int32)
    indices = tf.math.argmax(track_dists, output_type=tf.int32, axis=1)
    arr1 = indices * mask
    additional = tf.cast(track_dists[:, 9] == 200, tf.int32) * 9
    result = arr1 + additional
    
    return result

@tf.function
def compute_target_angle(track_dists):

    max_track_dist_idx = get_max_dist_idx(track_dists)

    max_dist_angle = max_track_dist_idx * 10 - 90
    return tf.cast(max_dist_angle, tf.float32) * RAD_PER_DEG

@tf.function
def compute_target_angle_2(angle_probs):

    max_track_dist_idx = tf.math.argmax(angle_probs, output_type=tf.int32, axis=1)

    max_dist_angle = max_track_dist_idx * 10 - 90
    return tf.cast(max_dist_angle, tf.float32) * RAD_PER_DEG

# %%
@tf.function
def is_off_track(trackPos, angle):
    return tf.abs(trackPos) > 1.0 and tf.abs(angle) > PI_HALF

# %%
@tf.function
def compute_steering(data):

    target_angle = data[:, 1] * RAD_PER_DEG
    lookahead = data[:, 0]


    raw_steering_angle_rad = -tf.math.atan(
        (PURE_PURSUIT_2L * tf.math.sin(target_angle)) / (lookahead + 1e-7))

    raw_steering_angle_deg = raw_steering_angle_rad * DEG_PER_RAD

    normalized_steering_angle = tf.clip_by_value(raw_steering_angle_deg / MAX_STEERING_ANGLE_DEG, -1.0, 1.0)


    return normalized_steering_angle

# %% [markdown]
# ### Perception Block Warm Start

# %%
learning_rate=1e-3

input_p = Input(shape=(X_train.shape[1]-2,))
l_p = Dense(16, activation="relu",kernel_initializer='he_normal', name='dense_1')(input_p)
l_p = Dense(8, activation="relu",kernel_initializer='he_normal', name='dense_3')(l_p)
#lookahead = Dense(1, activation="relu",kernel_initializer='he_normal', name='lookahead')(l_p)
output = Dense(2,kernel_initializer='he_normal', name='lookahead')(l_p)

model_perception = tf.keras.Model(input_p, output)

model_perception.compile(optimizer=Adam(learning_rate),loss='mean_absolute_error',metrics=['mae'],
             loss_weights=[1, 0])
model_perception.summary()

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=5, min_delta=0.0001, min_lr=0)
stats = model_perception.fit(X_train.iloc[:,:-2],X_train.iloc[:,-2:],validation_data=(X_val.iloc[:,:-2],X_val.iloc[:,-2:]),batch_size=512,epochs=512,callbacks=[reduce_lr])

# %% [markdown]
# ### Collective Training

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=5, min_delta=0.0001, min_lr=0)

# %%
learning_rate=1e-3

input_ = Input(shape=(X_train.shape[1]-2,))
target_angle_lookahead = model_perception(input_)
# out_p = Lambda(compute_steering, name='pp_based_steering')([input_p[:,0:19], lookahead[:,0]])
steer = Lambda(compute_steering, name='pp_based_steering')(target_angle_lookahead)

model = tf.keras.Model(input_, [steer, target_angle_lookahead])

model.compile(optimizer=Adam(learning_rate),loss='mean_absolute_error',metrics=['mae'],
             loss_weights=[1, 0])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 29)]              0
#
#  model (Functional)          (None, 2)                 634
#
#  pp_based_steering (Lambda)  (None,)                   0
#
# =================================================================
# Total params: 634
# Trainable params: 634
# Non-trainable params: 0
# _________________________________________________________________

# %%
stats = model.fit(X_train.iloc[:,:-2],Y_train,validation_data=(X_val.iloc[:,:-2],Y_val),batch_size=512,epochs=50,callbacks=[reduce_lr])
# Out:
# Epoch 1/50
# 1015/1015 [==============================] - 3s 2ms/step - loss: 0.0799 - pp_based_steering_loss: 0.0799 - model_loss: 86.7299 - pp_based_steering_mae: 0.0799 - model_mae: 86.7299 - val_loss: 0.0396 - val_pp_based_steering_loss: 0.0396 - val_model_loss: 94.9385 - val_pp_based_steering_mae: 0.0396 - val_model_mae: 94.9385 - lr: 0.0010
# Epoch 2/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0326 - pp_based_steering_loss: 0.0326 - model_loss: 99.6300 - pp_based_steering_mae: 0.0326 - model_mae: 99.6300 - val_loss: 0.0280 - val_pp_based_steering_loss: 0.0280 - val_model_loss: 104.6673 - val_pp_based_steering_mae: 0.0280 - val_model_mae: 104.6673 - lr: 0.0010
# Epoch 3/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0255 - pp_based_steering_loss: 0.0255 - model_loss: 107.0609 - pp_based_steering_mae: 0.0255 - model_mae: 107.0609 - val_loss: 0.0240 - val_pp_based_steering_loss: 0.0240 - val_model_loss: 109.9746 - val_pp_based_steering_mae: 0.0240 - val_model_mae: 109.9746 - lr: 0.0010
# Epoch 4/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0222 - pp_based_steering_loss: 0.0222 - model_loss: 112.5608 - pp_based_steering_mae: 0.0222 - model_mae: 112.5608 - val_loss: 0.0214 - val_pp_based_steering_loss: 0.0214 - val_model_loss: 114.9167 - val_pp_based_steering_mae: 0.0214 - val_model_mae: 114.9167 - lr: 0.0010
# Epoch 5/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0200 - pp_based_steering_loss: 0.0200 - model_loss: 116.4389 - pp_based_steering_mae: 0.0200 - model_mae: 116.4389 - val_loss: 0.0194 - val_pp_based_steering_loss: 0.0194 - val_model_loss: 117.9407 - val_pp_based_steering_mae: 0.0194 - val_model_mae: 117.9407 - lr: 0.0010
# Epoch 6/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0185 - pp_based_steering_loss: 0.0185 - model_loss: 118.8094 - pp_based_steering_mae: 0.0185 - model_mae: 118.8094 - val_loss: 0.0180 - val_pp_based_steering_loss: 0.0180 - val_model_loss: 119.7346 - val_pp_based_steering_mae: 0.0180 - val_model_mae: 119.7346 - lr: 0.0010
# Epoch 7/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0173 - pp_based_steering_loss: 0.0173 - model_loss: 119.8941 - pp_based_steering_mae: 0.0173 - model_mae: 119.8941 - val_loss: 0.0169 - val_pp_based_steering_loss: 0.0169 - val_model_loss: 121.9850 - val_pp_based_steering_mae: 0.0169 - val_model_mae: 121.9850 - lr: 0.0010
# Epoch 8/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0159 - pp_based_steering_loss: 0.0159 - model_loss: 123.2431 - pp_based_steering_mae: 0.0159 - model_mae: 123.2431 - val_loss: 0.0157 - val_pp_based_steering_loss: 0.0157 - val_model_loss: 124.6918 - val_pp_based_steering_mae: 0.0157 - val_model_mae: 124.6918 - lr: 0.0010
# Epoch 9/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0149 - pp_based_steering_loss: 0.0149 - model_loss: 126.9466 - pp_based_steering_mae: 0.0149 - model_mae: 126.9466 - val_loss: 0.0146 - val_pp_based_steering_loss: 0.0146 - val_model_loss: 129.7102 - val_pp_based_steering_mae: 0.0146 - val_model_mae: 129.7102 - lr: 0.0010
# Epoch 10/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0135 - pp_based_steering_loss: 0.0135 - model_loss: 131.8129 - pp_based_steering_mae: 0.0135 - model_mae: 131.8129 - val_loss: 0.0130 - val_pp_based_steering_loss: 0.0130 - val_model_loss: 133.7748 - val_pp_based_steering_mae: 0.0130 - val_model_mae: 133.7748 - lr: 0.0010
# Epoch 11/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0126 - pp_based_steering_loss: 0.0126 - model_loss: 135.7941 - pp_based_steering_mae: 0.0126 - model_mae: 135.7941 - val_loss: 0.0129 - val_pp_based_steering_loss: 0.0129 - val_model_loss: 135.9963 - val_pp_based_steering_mae: 0.0128 - val_model_mae: 135.9963 - lr: 0.0010
# Epoch 12/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0118 - pp_based_steering_loss: 0.0118 - model_loss: 136.4599 - pp_based_steering_mae: 0.0118 - model_mae: 136.4599 - val_loss: 0.0115 - val_pp_based_steering_loss: 0.0115 - val_model_loss: 136.6389 - val_pp_based_steering_mae: 0.0115 - val_model_mae: 136.6389 - lr: 0.0010
# Epoch 13/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0111 - pp_based_steering_loss: 0.0111 - model_loss: 136.3140 - pp_based_steering_mae: 0.0111 - model_mae: 136.3140 - val_loss: 0.0114 - val_pp_based_steering_loss: 0.0114 - val_model_loss: 134.5223 - val_pp_based_steering_mae: 0.0114 - val_model_mae: 134.5223 - lr: 0.0010
# Epoch 14/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0107 - pp_based_steering_loss: 0.0107 - model_loss: 135.0212 - pp_based_steering_mae: 0.0107 - model_mae: 135.0212 - val_loss: 0.0107 - val_pp_based_steering_loss: 0.0107 - val_model_loss: 135.2659 - val_pp_based_steering_mae: 0.0107 - val_model_mae: 135.2659 - lr: 0.0010
# Epoch 15/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0102 - pp_based_steering_loss: 0.0102 - model_loss: 136.3397 - pp_based_steering_mae: 0.0102 - model_mae: 136.3397 - val_loss: 0.0101 - val_pp_based_steering_loss: 0.0101 - val_model_loss: 137.2762 - val_pp_based_steering_mae: 0.0101 - val_model_mae: 137.2762 - lr: 0.0010
# Epoch 16/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0095 - pp_based_steering_loss: 0.0095 - model_loss: 137.6189 - pp_based_steering_mae: 0.0095 - model_mae: 137.6189 - val_loss: 0.0096 - val_pp_based_steering_loss: 0.0096 - val_model_loss: 138.2641 - val_pp_based_steering_mae: 0.0096 - val_model_mae: 138.2641 - lr: 0.0010
# Epoch 17/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0093 - pp_based_steering_loss: 0.0093 - model_loss: 138.4080 - pp_based_steering_mae: 0.0093 - model_mae: 138.4080 - val_loss: 0.0101 - val_pp_based_steering_loss: 0.0101 - val_model_loss: 138.6946 - val_pp_based_steering_mae: 0.0101 - val_model_mae: 138.6946 - lr: 0.0010
# Epoch 18/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0091 - pp_based_steering_loss: 0.0091 - model_loss: 139.0400 - pp_based_steering_mae: 0.0091 - model_mae: 139.0400 - val_loss: 0.0092 - val_pp_based_steering_loss: 0.0092 - val_model_loss: 139.4983 - val_pp_based_steering_mae: 0.0091 - val_model_mae: 139.4983 - lr: 0.0010
# Epoch 19/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0089 - pp_based_steering_loss: 0.0089 - model_loss: 139.3608 - pp_based_steering_mae: 0.0089 - model_mae: 139.3608 - val_loss: 0.0091 - val_pp_based_steering_loss: 0.0091 - val_model_loss: 139.8018 - val_pp_based_steering_mae: 0.0091 - val_model_mae: 139.8018 - lr: 0.0010
# Epoch 20/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0088 - pp_based_steering_loss: 0.0088 - model_loss: 139.6210 - pp_based_steering_mae: 0.0088 - model_mae: 139.6210 - val_loss: 0.0088 - val_pp_based_steering_loss: 0.0088 - val_model_loss: 139.9895 - val_pp_based_steering_mae: 0.0088 - val_model_mae: 139.9895 - lr: 0.0010
# Epoch 21/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0087 - pp_based_steering_loss: 0.0087 - model_loss: 139.9298 - pp_based_steering_mae: 0.0087 - model_mae: 139.9298 - val_loss: 0.0089 - val_pp_based_steering_loss: 0.0089 - val_model_loss: 140.2245 - val_pp_based_steering_mae: 0.0089 - val_model_mae: 140.2245 - lr: 0.0010
# Epoch 22/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0085 - pp_based_steering_loss: 0.0085 - model_loss: 140.1389 - pp_based_steering_mae: 0.0085 - model_mae: 140.1389 - val_loss: 0.0088 - val_pp_based_steering_loss: 0.0088 - val_model_loss: 140.3179 - val_pp_based_steering_mae: 0.0088 - val_model_mae: 140.3179 - lr: 0.0010
# Epoch 23/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0085 - pp_based_steering_loss: 0.0085 - model_loss: 140.2635 - pp_based_steering_mae: 0.0085 - model_mae: 140.2635 - val_loss: 0.0086 - val_pp_based_steering_loss: 0.0086 - val_model_loss: 140.8390 - val_pp_based_steering_mae: 0.0086 - val_model_mae: 140.8390 - lr: 0.0010
# Epoch 24/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0084 - pp_based_steering_loss: 0.0084 - model_loss: 140.5256 - pp_based_steering_mae: 0.0084 - model_mae: 140.5256 - val_loss: 0.0085 - val_pp_based_steering_loss: 0.0085 - val_model_loss: 140.7602 - val_pp_based_steering_mae: 0.0085 - val_model_mae: 140.7602 - lr: 0.0010
# Epoch 25/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0083 - pp_based_steering_loss: 0.0083 - model_loss: 140.7164 - pp_based_steering_mae: 0.0083 - model_mae: 140.7164 - val_loss: 0.0086 - val_pp_based_steering_loss: 0.0086 - val_model_loss: 140.9150 - val_pp_based_steering_mae: 0.0086 - val_model_mae: 140.9150 - lr: 0.0010
# Epoch 26/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0082 - pp_based_steering_loss: 0.0082 - model_loss: 140.9629 - pp_based_steering_mae: 0.0082 - model_mae: 140.9629 - val_loss: 0.0084 - val_pp_based_steering_loss: 0.0084 - val_model_loss: 141.2854 - val_pp_based_steering_mae: 0.0084 - val_model_mae: 141.2854 - lr: 0.0010
# Epoch 27/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0082 - pp_based_steering_loss: 0.0082 - model_loss: 140.9831 - pp_based_steering_mae: 0.0082 - model_mae: 140.9831 - val_loss: 0.0083 - val_pp_based_steering_loss: 0.0083 - val_model_loss: 140.7772 - val_pp_based_steering_mae: 0.0083 - val_model_mae: 140.7772 - lr: 0.0010
# Epoch 28/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0084 - pp_based_steering_loss: 0.0084 - model_loss: 141.2123 - pp_based_steering_mae: 0.0084 - model_mae: 141.2123 - val_loss: 0.0095 - val_pp_based_steering_loss: 0.0095 - val_model_loss: 144.2325 - val_pp_based_steering_mae: 0.0095 - val_model_mae: 144.2325 - lr: 0.0010
# Epoch 29/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0085 - pp_based_steering_loss: 0.0085 - model_loss: 143.4270 - pp_based_steering_mae: 0.0085 - model_mae: 143.4270 - val_loss: 0.0082 - val_pp_based_steering_loss: 0.0082 - val_model_loss: 143.4202 - val_pp_based_steering_mae: 0.0082 - val_model_mae: 143.4202 - lr: 0.0010
# Epoch 30/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0080 - pp_based_steering_loss: 0.0080 - model_loss: 143.5012 - pp_based_steering_mae: 0.0080 - model_mae: 143.5012 - val_loss: 0.0080 - val_pp_based_steering_loss: 0.0080 - val_model_loss: 144.1700 - val_pp_based_steering_mae: 0.0080 - val_model_mae: 144.1700 - lr: 0.0010
# Epoch 31/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0078 - pp_based_steering_loss: 0.0078 - model_loss: 144.0475 - pp_based_steering_mae: 0.0078 - model_mae: 144.0475 - val_loss: 0.0079 - val_pp_based_steering_loss: 0.0079 - val_model_loss: 144.1491 - val_pp_based_steering_mae: 0.0079 - val_model_mae: 144.1491 - lr: 0.0010
# Epoch 32/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0077 - pp_based_steering_loss: 0.0077 - model_loss: 144.3271 - pp_based_steering_mae: 0.0077 - model_mae: 144.3271 - val_loss: 0.0079 - val_pp_based_steering_loss: 0.0079 - val_model_loss: 144.4979 - val_pp_based_steering_mae: 0.0079 - val_model_mae: 144.4979 - lr: 0.0010
# Epoch 33/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0076 - pp_based_steering_loss: 0.0076 - model_loss: 144.4705 - pp_based_steering_mae: 0.0076 - model_mae: 144.4705 - val_loss: 0.0077 - val_pp_based_steering_loss: 0.0077 - val_model_loss: 144.5925 - val_pp_based_steering_mae: 0.0077 - val_model_mae: 144.5925 - lr: 0.0010
# Epoch 34/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0078 - pp_based_steering_loss: 0.0078 - model_loss: 145.3266 - pp_based_steering_mae: 0.0078 - model_mae: 145.3266 - val_loss: 0.0080 - val_pp_based_steering_loss: 0.0080 - val_model_loss: 146.1511 - val_pp_based_steering_mae: 0.0080 - val_model_mae: 146.1511 - lr: 0.0010
# Epoch 35/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0076 - pp_based_steering_loss: 0.0076 - model_loss: 145.7816 - pp_based_steering_mae: 0.0076 - model_mae: 145.7816 - val_loss: 0.0077 - val_pp_based_steering_loss: 0.0077 - val_model_loss: 145.8604 - val_pp_based_steering_mae: 0.0077 - val_model_mae: 145.8604 - lr: 0.0010
# Epoch 36/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0076 - pp_based_steering_loss: 0.0076 - model_loss: 145.6838 - pp_based_steering_mae: 0.0076 - model_mae: 145.6838 - val_loss: 0.0076 - val_pp_based_steering_loss: 0.0076 - val_model_loss: 145.6705 - val_pp_based_steering_mae: 0.0076 - val_model_mae: 145.6705 - lr: 0.0010
# Epoch 37/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0075 - pp_based_steering_loss: 0.0075 - model_loss: 145.6586 - pp_based_steering_mae: 0.0075 - model_mae: 145.6586 - val_loss: 0.0076 - val_pp_based_steering_loss: 0.0076 - val_model_loss: 145.9019 - val_pp_based_steering_mae: 0.0076 - val_model_mae: 145.9019 - lr: 0.0010
# Epoch 38/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0073 - pp_based_steering_loss: 0.0073 - model_loss: 145.7772 - pp_based_steering_mae: 0.0073 - model_mae: 145.7772 - val_loss: 0.0074 - val_pp_based_steering_loss: 0.0074 - val_model_loss: 146.0481 - val_pp_based_steering_mae: 0.0074 - val_model_mae: 146.0481 - lr: 0.0010
# Epoch 39/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0073 - pp_based_steering_loss: 0.0073 - model_loss: 145.9175 - pp_based_steering_mae: 0.0073 - model_mae: 145.9175 - val_loss: 0.0075 - val_pp_based_steering_loss: 0.0075 - val_model_loss: 145.9477 - val_pp_based_steering_mae: 0.0075 - val_model_mae: 145.9477 - lr: 0.0010
# Epoch 40/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0072 - pp_based_steering_loss: 0.0072 - model_loss: 146.0295 - pp_based_steering_mae: 0.0072 - model_mae: 146.0295 - val_loss: 0.0073 - val_pp_based_steering_loss: 0.0073 - val_model_loss: 146.0499 - val_pp_based_steering_mae: 0.0073 - val_model_mae: 146.0499 - lr: 0.0010
# Epoch 41/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0072 - pp_based_steering_loss: 0.0072 - model_loss: 146.0954 - pp_based_steering_mae: 0.0072 - model_mae: 146.0954 - val_loss: 0.0076 - val_pp_based_steering_loss: 0.0076 - val_model_loss: 146.4312 - val_pp_based_steering_mae: 0.0076 - val_model_mae: 146.4312 - lr: 0.0010
# Epoch 42/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0073 - pp_based_steering_loss: 0.0073 - model_loss: 146.2836 - pp_based_steering_mae: 0.0073 - model_mae: 146.2836 - val_loss: 0.0074 - val_pp_based_steering_loss: 0.0074 - val_model_loss: 146.1874 - val_pp_based_steering_mae: 0.0074 - val_model_mae: 146.1874 - lr: 0.0010
# Epoch 43/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0071 - pp_based_steering_loss: 0.0071 - model_loss: 146.2537 - pp_based_steering_mae: 0.0071 - model_mae: 146.2537 - val_loss: 0.0075 - val_pp_based_steering_loss: 0.0075 - val_model_loss: 145.7496 - val_pp_based_steering_mae: 0.0075 - val_model_mae: 145.7496 - lr: 0.0010
# Epoch 44/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0072 - pp_based_steering_loss: 0.0072 - model_loss: 146.3586 - pp_based_steering_mae: 0.0072 - model_mae: 146.3586 - val_loss: 0.0074 - val_pp_based_steering_loss: 0.0074 - val_model_loss: 146.4902 - val_pp_based_steering_mae: 0.0074 - val_model_mae: 146.4902 - lr: 0.0010
# Epoch 45/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0071 - pp_based_steering_loss: 0.0071 - model_loss: 146.3468 - pp_based_steering_mae: 0.0071 - model_mae: 146.3468 - val_loss: 0.0073 - val_pp_based_steering_loss: 0.0073 - val_model_loss: 146.5506 - val_pp_based_steering_mae: 0.0073 - val_model_mae: 146.5506 - lr: 0.0010
# Epoch 46/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0069 - pp_based_steering_loss: 0.0069 - model_loss: 146.3513 - pp_based_steering_mae: 0.0069 - model_mae: 146.3513 - val_loss: 0.0072 - val_pp_based_steering_loss: 0.0072 - val_model_loss: 146.4858 - val_pp_based_steering_mae: 0.0072 - val_model_mae: 146.4858 - lr: 1.0000e-04
# Epoch 47/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0069 - pp_based_steering_loss: 0.0069 - model_loss: 146.3765 - pp_based_steering_mae: 0.0069 - model_mae: 146.3765 - val_loss: 0.0072 - val_pp_based_steering_loss: 0.0072 - val_model_loss: 146.5728 - val_pp_based_steering_mae: 0.0072 - val_model_mae: 146.5728 - lr: 1.0000e-04
# Epoch 48/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0069 - pp_based_steering_loss: 0.0069 - model_loss: 146.4092 - pp_based_steering_mae: 0.0069 - model_mae: 146.4092 - val_loss: 0.0072 - val_pp_based_steering_loss: 0.0072 - val_model_loss: 146.4872 - val_pp_based_steering_mae: 0.0072 - val_model_mae: 146.4872 - lr: 1.0000e-04
# Epoch 49/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0069 - pp_based_steering_loss: 0.0069 - model_loss: 146.4089 - pp_based_steering_mae: 0.0069 - model_mae: 146.4089 - val_loss: 0.0071 - val_pp_based_steering_loss: 0.0071 - val_model_loss: 146.5438 - val_pp_based_steering_mae: 0.0071 - val_model_mae: 146.5438 - lr: 1.0000e-04
# Epoch 50/50
# 1015/1015 [==============================] - 2s 2ms/step - loss: 0.0069 - pp_based_steering_loss: 0.0069 - model_loss: 146.4084 - pp_based_steering_mae: 0.0069 - model_mae: 146.4084 - val_loss: 0.0071 - val_pp_based_steering_loss: 0.0071 - val_model_loss: 146.5599 - val_pp_based_steering_mae: 0.0071 - val_model_mae: 146.5599 - lr: 1.0000e-04

# %%
model.predict(X_val.iloc[:,:-2])
# Out:
# 4314/4314 [==============================] - 2s 568us/step
# [array([0.32091972, 0.3201259 , 0.32051766, ..., 0.02996011, 0.02636032,
#         0.02286981], dtype=float32),
#  array([[ -40.448086,   95.27168 ],
#         [ -40.55679 ,   95.15593 ],
#         [ -40.515858,   95.01131 ],
#         ...,
#         [-257.37338 ,  143.92694 ],
#         [-265.47214 ,  147.6991  ],
#         [-272.96082 ,  151.5311  ]], dtype=float32)]

# %%
model.save(MODEL_SAVE_DIR.joinpath('model.h5'))

# %%
import matplotlib.pyplot as plt
import seaborn as sns
custom_params = {"axes.spines.right": False, "axes.spines.top": False}
sns.set_theme(style="ticks", rc=custom_params)

# %%
fig, ax = plt.subplots(dpi=400)
ax.plot(stats.history['loss'])
ax.plot(stats.history['val_loss'])
ax.legend(['Training Loss', 'Validation Loss'])
ax.set_xlabel("Epochs")
ax.set_ylabel("Mean Absolute Error")

fig.savefig("pi_loss.png")

# %%
preds = model.predict(X_val.iloc[:,:-2])
# Out:
# 4314/4314 [==============================] - 2s 562us/step

# %%
plt.hist(preds[1])
# Out:
# (array([[ 1530.,  2639.,  4513.,  3077.,  6039., 38545., 47010.,  4574.,
#          23376.,  6736.],
#         [    0.,     0.,     0.,     0.,     0.,     0.,  3065., 75045.,
#          59114.,   815.]]),
#  array([-790.7022  , -676.90955 , -563.1169  , -449.32422 , -335.53156 ,
#         -221.7389  , -107.94624 ,    5.846414,  119.63908 ,  233.43173 ,
#          347.2244  ], dtype=float32),
#  <a list of 2 BarContainer objects>)

# %%
model = load_model("PI_model_new/model.h5", custom_objects={'compute_steering': compute_steering,
                                                               'compute_target_angle': compute_target_angle,
                                                               'get_max_dist_idx': get_max_dist_idx})

# %%
tf.keras.utils.plot_model(model)
